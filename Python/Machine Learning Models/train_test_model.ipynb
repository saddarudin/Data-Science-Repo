# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('carprices.csv')
df.head(5)
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
x=df[["Mileage", "Age(yrs)"]]
y=df['Sell Price($)']
x.head(5)
# Out:
#    Mileage  Age(yrs)
# 0    69000         6
# 1    35000         3
# 2    57000         5
# 3    22500         2
# 4    46000         4

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20) #test size is 20%

# %%
len(x_train), len(x_test), len(y_train), len(y_test)
# Out:
# (16, 4, 16, 4)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([34298.28852136, 23905.13121636, 27145.46175238, 21948.88309988])

# %%
y_test
# Out:
# 1     34000
# 17    19700
# 6     32000
# 0     18000
# Name: Sell Price($), dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.720464365090427
