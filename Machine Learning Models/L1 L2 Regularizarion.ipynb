# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso # L1 Regularization
from sklearn.linear_model import Ridge # L2 Regularization

# %%
df = pd.read_csv('Melbourne.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df = df.drop(['Address', 'Date', 'Distance', 'Postcode', 'YearBuilt', 'Lattitude', 'Longtitude'], axis='columns')
df.shape
# Out:
# (34857, 14)

# %%
df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG  Bedroom2  Bathroom  Car  \
# 0  Abbotsford      2    h        NaN     SS  Jellis       2.0       1.0  1.0
# 1  Abbotsford      2    h  1480000.0      S  Biggin       2.0       1.0  1.0
# 2  Abbotsford      2    h  1035000.0      S  Biggin       2.0       1.0  0.0
# 3  Abbotsford      3    u        NaN     VB  Rounds       3.0       2.0  1.0
# 4  Abbotsford      3    h  1465000.0     SP  Biggin       3.0       2.0  0.0
#
#    Landsize  BuildingArea         CouncilArea             Regionname  \
# 0     126.0           NaN  Yarra City Council  Northern Metropolitan
# 1     202.0           NaN  Yarra City Council  Northern Metropolitan
# 2     156.0          79.0  Yarra City Council  Northern Metropolitan
# 3       0.0           NaN  Yarra City Council  Northern Metropolitan
# 4     134.0         150.0  Yarra City Council  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Price.fillna(df.Price.mean(), inplace=True)
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Bedroom2
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
#         ...
# 34852    4.0
# 34853    2.0
# 34854    2.0
# 34855    NaN
# 34856    2.0
# Name: Bedroom2, Length: 34857, dtype: float64

# %%
df.Bedroom2.fillna(int(df.Bedroom2.mean()), inplace=True)
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Bedroom2             0
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Bathroom.fillna(int(df.Bathroom.mean()), inplace=True)
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Bedroom2             0
# Bathroom             0
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Car.fillna(df.Car.median(), inplace=True)
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Landsize.fillna(int(df.Landsize.mean()), inplace=True)
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.BuildingArea.fillna(int(df.BuildingArea.mean()), inplace=True)
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      3
# Regionname       3
# Propertycount    3
# dtype: int64

# %%
df=df.dropna()
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.head()
# Out:
#        Suburb  Rooms Type         Price Method SellerG  Bedroom2  Bathroom  \
# 0  Abbotsford      2    h  1.050173e+06     SS  Jellis       2.0       1.0
# 1  Abbotsford      2    h  1.480000e+06      S  Biggin       2.0       1.0
# 2  Abbotsford      2    h  1.035000e+06      S  Biggin       2.0       1.0
# 3  Abbotsford      3    u  1.050173e+06     VB  Rounds       3.0       2.0
# 4  Abbotsford      3    h  1.465000e+06     SP  Biggin       3.0       2.0
#
#    Car  Landsize  BuildingArea         CouncilArea             Regionname  \
# 0  1.0     126.0         160.0  Yarra City Council  Northern Metropolitan
# 1  1.0     202.0         160.0  Yarra City Council  Northern Metropolitan
# 2  0.0     156.0          79.0  Yarra City Council  Northern Metropolitan
# 3  1.0       0.0         160.0  Yarra City Council  Northern Metropolitan
# 4  0.0     134.0         150.0  Yarra City Council  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.Suburb=le.fit_transform(df.Suburb)
df.head()
# Out:
# <ipython-input-39-3ecb9e133053>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Suburb=le.fit_transform(df.Suburb)
#    Suburb  Rooms Type         Price Method SellerG  Bedroom2  Bathroom  Car  \
# 0       0      2    h  1.050173e+06     SS  Jellis       2.0       1.0  1.0
# 1       0      2    h  1.480000e+06      S  Biggin       2.0       1.0  1.0
# 2       0      2    h  1.035000e+06      S  Biggin       2.0       1.0  0.0
# 3       0      3    u  1.050173e+06     VB  Rounds       3.0       2.0  1.0
# 4       0      3    h  1.465000e+06     SP  Biggin       3.0       2.0  0.0
#
#    Landsize  BuildingArea         CouncilArea             Regionname  \
# 0     126.0         160.0  Yarra City Council  Northern Metropolitan
# ...

# %%
df.Type = le.fit_transform(df.Type)
df.Method = le.fit_transform(df.Method)
df.SellerG = le.fit_transform(df.SellerG)
df.CouncilArea = le.fit_transform(df.CouncilArea)
df.Regionname = le.fit_transform(df.Regionname)
df.head()
# Out:
# <ipython-input-40-e4583144adc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Type = le.fit_transform(df.Type)
# <ipython-input-40-e4583144adc3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Method = le.fit_transform(df.Method)
# <ipython-input-40-e4583144adc3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x = df.drop(['Price'], axis='columns')
y = df.Price
x.head()
# Out:
#    Suburb  Rooms  Type  Method  SellerG  Bedroom2  Bathroom  Car  Landsize  \
# 0       0      2     0       6      155       2.0       1.0  1.0     126.0
# 1       0      2     0       2       33       2.0       1.0  1.0     202.0
# 2       0      2     0       2       33       2.0       1.0  0.0     156.0
# 3       0      3     2       7      296       3.0       2.0  1.0       0.0
# 4       0      3     0       5       33       3.0       2.0  0.0     134.0
#
#    BuildingArea  CouncilArea  Regionname  Propertycount
# 0         160.0           31           2         4019.0
# 1         160.0           31           2         4019.0
# 2          79.0           31           2         4019.0
# 3         160.0           31           2         4019.0
# 4         150.0           31           2         4019.0

# %%
y.head()
# Out:
# 0    1.050173e+06
# 1    1.480000e+06
# 2    1.035000e+06
# 3    1.050173e+06
# 4    1.465000e+06
# Name: Price, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)
x_test.shape
# Out:
# (10457, 13)

# %%
x_train.shape
# Out:
# (24397, 13)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Accuracy of model on testing data set

# %%
model.score(x_test, y_test)
# Out:
# 0.22254816493583063

# %% [markdown]
# # Accuracy of model on training data set on which it is already trained.

# %%
model.score(x_train, y_train)
# Out:
# 0.21996568714356834

# %% [markdown]
# # L1 Regularization

# %%
model1 = Lasso()
model1.fit(x_train, y_train)
# Out:
# Lasso()

# %%
print(f"Training Data Accuracy: {model1.score(x_train, y_train)}\nTesting Data Accuracy: {model1.score(x_test, y_test)}")
# Out:
# Training Data Accuracy: 0.21996568706717967
# Testing Data Accuracy: 0.2225480734846651

# %% [markdown]
# # L2 Regularization

# %%
model2 = Ridge()
model2.fit(x_train, y_train)
# Out:
# Ridge()

# %%
print(f"Training Data Accuracy: {model2.score(x_train, y_train)}\nTesting Data Accuracy: {model2.score(x_test, y_test)}")
# Out:
# Training Data Accuracy: 0.21996568601791222
# Testing Data Accuracy: 0.22254812793178713
